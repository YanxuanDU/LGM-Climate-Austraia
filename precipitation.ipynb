# %%
import xarray as xr
import numpy as np
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %matplotlib inline

# %%
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cfeature
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. LGM model data read in

# %%
# Read in data
# 1. CCSM4
url='/g/data/ob22/yd3797/CMIP5DATA/lgm/evspsbl_CCSM4_lgm_r1i1p1_1800_1900_r240x120.nc'
ccsm4_ds = xr.open_dataset(url)
aveml_CCSM = ccsm4_ds.evspsbl

# %%
# 2. CNRM
url='/g/data/ob22/yd3797/CMIP5DATA/lgm/evspsbl_CNRM-CM5_lgm_r1i1p1_1800_1999_r240x120.nc'
cnrm_ds = xr.open_dataset(url)
evspsbll_cnrm = cnrm_ds.evspsbl

# %%
# 3. FGO
url='/g/data/ob22/yd3797/CMIP5DATA/lgm/evspsbl_FGOALS-g2_lgm_r1i1p1_0550_0649_r240x120.nc'
fgo_ds = xr.open_dataset(url)
evspsbll_fgo = fgo_ds.evspsbl

# %%
# 4. GISS
url='/g/data/ob22/yd3797/CMIP5DATA/lgm/evspsbl_GISS-E2-R_lgm_r1i1p1_3000_3099_r240x120.nc'
giss_ds = xr.open_dataset(url)
evspsbll_giss = giss_ds.evspsbl

# %%
# 5. IPSL
url='/g/data/ob22/yd3797/CMIP5DATA/lgm/evspsbl_IPSL-CM5A-LR_lgm_r1i1p1_2601_2800_r240x120.nc'
ipsl_ds = xr.open_dataset(url)
evspsbll_ipsl = ipsl_ds.evspsbl

# %%
# 6. MIROC
url='/g/data/ob22/yd3797/CMIP5DATA/lgm/evspsbl_MIROC-ESM_lgm_r1i1p1_4600_4699_r240x120.nc'
mir_ds = xr.open_dataset(url)
evspsbll_mir = mir_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(array[self.key], dtype=None)

# %%
# 7. MPI
url='/g/data/ob22/yd3797/CMIP5DATA/lgm/evspsbl_MPI-ESM-P_lgm_r1i1p1_1850_1949_r240x120.nc'
mpi5_ds = xr.open_dataset(url)
evspsbll_mpi5 = mpi5_ds.evspsbl

# %%
# 8. MRI-CGCM3
url='/g/data/ob22/yd3797/CMIP5DATA/lgm/evspsbl_MRI-CGCM3_lgm_r1i1p1_2501_2600_r240x120.nc'
cgcm_ds = xr.open_dataset(url)
evspsbll_cgcm = cgcm_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(array[self.key], dtype=None)

# %%
# 1. AWI-ESM-1-1-LR Model
url='/g/data/ob22/yd3797/CMIP6DATA/lgm/evspsbl_AWI-ESM-1-1-LR_lgm_r1i1p1_3901_4000_r240x120.nc'
awi_ds = xr.open_dataset(url)
evspsbll_awi = awi_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   return np.asarray(array[self.key], dtype=None)

# %%
# 2. INM-CM4-8 model
url1='/g/data/ob22/yd3797/CMIP6DATA/lgm/evspsbl_INM-CM4-8_lgm_r1i1p1_1900_2099_r240x120.nc'
inm_ds = xr.open_dataset(url1)
evspsbll_inm = inm_ds.evspsbl

# %%
# 3. MIROC-ES2L model
url3='/g/data/ob22/yd3797/CMIP6DATA/lgm/evspsbl_MIROC-ES2L_lgm_r1i1p1_3200_3299_r240x120.nc'
mir_ds6 = xr.open_dataset(url3)
evspsbll_mir6 = mir_ds6.evspsbl

# %%
# 4. MPI-ESM1-2-LR model
url4='/g/data/ob22/yd3797/CMIP6DATA/lgm/evspsbl_MPI-ESM1-2-LR_lgm_r1i1p1_1850_2349_r240x120.nc'
mpi_ds = xr.open_dataset(url4)
evspsbll_mpi = mpi_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
# Select the first 100 years, convert to mm/ day

# %%
#CCSM4
evpl_ccsm_100C = aveml_CCSM * 86400

# %%
#CNRM
evpl_cnrm_100 = evspsbll_cnrm.sel(time=slice(None, '1899-12-16'))
evpl_cnrm_100C = evpl_cnrm_100 * 86400

# %%
#FGOALS-g2
evpl_fgo_100 = evspsbll_fgo.sel(time=slice(None, '0649-12-16'))
evpl_fgo_100C = evpl_fgo_100 * 86400

# %%
#GISS
evpl_giss_100C = evspsbll_giss * 86400

# %%
#IPSL
evpl_ipsl_100 = evspsbll_ipsl.sel(time=slice(None, '2700-12-16'))
evpl_ipsl_100C = evpl_ipsl_100 * 86400

# %%
#MIR
evpl_mir_100C = evspsbll_mir * 86400

# %%
# MPI5
evpl_mpi5_100C = evspsbll_mpi5 * 86400

# %%
# MRI-CGCM3
evpl_cgcm_100C = evspsbll_cgcm * 86400

# %%
evpl_awi_100C = evspsbll_awi * 86400

# %%
evpl_inm_100 = evspsbll_inm.sel(time=slice(None, '1999-12-16'))
evpl_inm_100C = evpl_inm_100 * 86400

# %%
evpl_mir6_100C = evspsbll_mir6 * 86400

# %%
evpl_mpi_100 = evspsbll_mpi.sel(time=slice(None, '1949-12-16'))
evpl_mpi_100C = evpl_mpi_100 * 86400

# %% [markdown]
# ### Time average of all the lgm data

# %%
# Time-ave for all models
ccsm_ml = evpl_ccsm_100C.mean(dim='time')
cnrm_ml = evpl_cnrm_100C.mean(dim='time')
fgo_ml = evpl_fgo_100C.mean(dim='time')
giss_ml = evpl_giss_100C.mean(dim='time')

# %%
# continued
ipsl_ml = evpl_ipsl_100C.mean(dim='time')
mir_ml = evpl_mir_100C.mean(dim='time')
mpi5_ml = evpl_mpi5_100C.mean(dim='time')
cgcm_ml = evpl_cgcm_100C.mean(dim='time')

# %%
awi_ml = evpl_awi_100C.mean(dim='time')
inm_ml = evpl_inm_100C.mean(dim='time')
mir6_ml = evpl_mir6_100C.mean(dim='time')
mpi_ml = evpl_mpi_100C.mean(dim='time')

# %%
# ccsm_ml.to_netcdf('ts5_ccsm_ml.nc')
# cnrm_ml.to_netcdf('ts5_cnrm_ml.nc')
# fgo_ml.to_netcdf('ts5_fgo_ml.nc')
# giss_ml.to_netcdf('ts5_giss_ml.nc')

# %%
# ipsl_ml.to_netcdf('ts5_ipsl_ml.nc')
# mir_ml.to_netcdf('ts5_mir_ml.nc')

# %%
# mpi5_ml.to_netcdf('ts5_mpi5_ml.nc')
# cgcm_ml.to_netcdf('ts5_cgcm_ml.nc')

# %% [markdown]
# ### seasonal change

# %%
ccsm_sl = evpl_ccsm_100C.groupby('time.season').mean(dim='time')
cnrm_sl = evpl_cnrm_100C.groupby('time.season').mean(dim='time')
fgo_sl = evpl_fgo_100C.groupby('time.season').mean(dim='time')
giss_sl = evpl_giss_100C.groupby('time.season').mean(dim='time')

# %%
ipsl_sl = evpl_ipsl_100C.groupby('time.season').mean(dim='time')
mir_sl = evpl_mir_100C.groupby('time.season').mean(dim='time')
mpi5_sl = evpl_mpi5_100C.groupby('time.season').mean(dim='time')
cgcm_sl = evpl_cgcm_100C.groupby('time.season').mean(dim='time')

# %%
awi_sl = evpl_awi_100C.groupby('time.season').mean(dim='time')
inm_sl = evpl_inm_100C.groupby('time.season').mean(dim='time')
mir6_sl = evpl_mir6_100C.groupby('time.season').mean(dim='time')
mpi_sl = evpl_mpi_100C.groupby('time.season').mean(dim='time')

# %%
ccsm_mml = prl_CCSM_100C.groupby('time.month').mean(dim='time')
cnrm_mml = prl_cnrm_100C.groupby('time.month').mean(dim='time')
fgo_mml = prl_fgo_100C.groupby('time.month').mean(dim='time')
giss_mml = prl_giss_100C.groupby('time.month').mean(dim='time')

# %%
ipsl_mml = prl_ipsl_100C.groupby('time.month').mean(dim='time')
mir_mml = prl_mir_100C.groupby('time.month').mean(dim='time')
mpi5_mml = prl_mpi5_100C.groupby('time.month').mean(dim='time')
cgcm_mml = prl_cgcm_100C.groupby('time.month').mean(dim='time')

# %%
awi_mml = prl_awi_100C.groupby('time.month').mean(dim='time')
inm_mml = prl_inm_100C.groupby('time.month').mean(dim='time')
mir6_mml = prl_mir6_100C.groupby('time.month').mean(dim='time')
mpi_mml = prl_mpi_100C.groupby('time.month').mean(dim='time')

# %%
# ccsm_mml.to_netcdf('ts5_ccsm_mml.nc')
# cnrm_mml.to_netcdf('ts5_cnrm_mml.nc')
# fgo_mml.to_netcdf('ts5_fgo_mml.nc')
# giss_mml.to_netcdf('ts5_giss_mml.nc')

# %% [markdown]
# ## 2. PI Model data Read in

# %%
# Read in data
# 1. CCSM4
url='/g/data/ob22/yd3797/CMIP5DATA/piControl/evspsbl_CCSM4_piControl_r1i1p1_0250_1300_r240x120.nc'
ccsm4_ds = xr.open_dataset(url)
evspsbl_CCSM = ccsm4_ds.evspsbl

# %%
# 2. CNRM
url='/g/data/ob22/yd3797/CMIP5DATA/piControl/evspsbl_CNRM-CM5_piControl_r1i1p1_1850_2699_r240x120.nc'
cnrm_ds = xr.open_dataset(url)
evspsbl_cnrm = cnrm_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
# 3. FGO
url='/g/data/ob22/yd3797/CMIP5DATA/piControl/evspsbl_FGOALS-g2_piControl_r1i1p1_0201_0900_r240x120.nc'
fgo_ds = xr.open_dataset(url)
evspsbl_fgo = fgo_ds.evspsbl

# %%
# 4. GISS
url='/g/data/ob22/yd3797/CMIP5DATA/piControl/evspsbl_GISS-E2-R_piControl_r1i1p1_3331_4530_r240x120.nc'
giss_ds = xr.open_dataset(url)
evspsbl_giss = giss_ds.evspsbl

# %%
# 5. IPSL
url='/g/data/ob22/yd3797/CMIP5DATA/piControl/evspsbl_IPSL-CM5A-LR_piControl_r1i1p1_1800_2799_r240x120.nc'
ipsl_ds = xr.open_dataset(url)
evspsbl_ipsl = ipsl_ds.evspsbl

# %%
# 6. MIROC
url='/g/data/ob22/yd3797/CMIP5DATA/piControl/evspsbl_MIROC-ESM_piControl_r1i1p1_1800_2429_r240x120.nc'
mir_ds = xr.open_dataset(url)
evspsbl_mir = mir_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
# 7. MPI
url='/g/data/ob22/yd3797/CMIP5DATA/piControl/evspsbl_MPI-ESM-P_piControl_r1i1p1_1850_3005_r240x120.nc'
mpi5_ds = xr.open_dataset(url)
evspsbl_mpi5 = mpi5_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
# 8. MRI-CGCM3
url='/g/data/ob22/yd3797/CMIP5DATA/piControl/evspsbl_MRI-CGCM3_piControl_r1i1p1_1851_2350_r240x120.nc'
cgcm_ds = xr.open_dataset(url)
evspsbl_cgcm = cgcm_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
# 1. AWI-ESM-1-1-LR Model
url='/g/data/ob22/yd3797/CMIP6DATA/piControl/evspsbl_AWI-ESM-1-1-LR_piControl_r1i1p1_1855_1954_r240x120.nc'
awi_ds = xr.open_dataset(url)
evspsbl_awi = awi_ds.evspsbl

# %%
# 2. INM-CM4-8 model
url1='/g/data/ob22/yd3797/CMIP6DATA/piControl/evspsbl_INM-CM4-8_piControl_r1i1p1_1850_2380_r240x120.nc'
inm_ds = xr.open_dataset(url1)
evspsbl_inm = inm_ds.evspsbl

# %%
# 3. MIROC-ES2L model
url3='/g/data/ob22/yd3797/CMIP6DATA/piControl/evspsbl_MIROC-ES2L_piControl_r1i1p1_1850_2349_r240x120.nc'
mir_ds6 = xr.open_dataset(url3)
evspsbl_mir6 = mir_ds6.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
# 4. MPI-ESM1-2-LR model
url4='/g/data/ob22/yd3797/CMIP6DATA/piControl/evspsbl_MPI-ESM1-2-LR_piControl_r1i1p1_1850_2849_r240x120.nc'
mpi_ds = xr.open_dataset(url4)
evspsbl_mpi = mpi_ds.evspsbl
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/coding/times.py:673: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.01/lib/python3.9/site-packages/xarray/core/indexing.py:423: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
# ...

# %%
# Select the first 100 years, convert to mm/ day
#CCSM
evp_CCSM_100 = evspsbl_CCSM.sel(time=slice(None, '0349-12-16'))
evp_CCSM_100C = evp_CCSM_100 * 86400

# %%
#CNRM
evp_cnrm_100 = evspsbl_cnrm.sel(time=slice(None, '1949-12-16'))
evp_cnrm_100C = evp_cnrm_100 * 86400

# %%
#FGOALS-g2
evp_fgo_100 = evspsbl_fgo.sel(time=slice(None, '0300-12-16'))
evp_fgo_100C = evp_fgo_100 * 86400

# %%
#GISS
evp_giss_100 = evspsbl_giss.sel(time=slice(None, '3430-12-16'))
evp_giss_100C = evp_giss_100 * 86400

# %%
#IPSL
evp_ipsl_100 = evspsbl_ipsl.sel(time=slice(None, '1899-12-16'))
evp_ipsl_100C = evp_ipsl_100 * 86400

# %%
#MIR
evp_mir_100 = evspsbl_mir.sel(time=slice(None, '1899-12-16'))
evp_mir_100C = evp_mir_100 * 86400

# %%
# MPI5
evp_mpi5_100 = evspsbl_mpi5.sel(time=slice(None, '1949-12-16'))
evp_mpi5_100C = evp_mpi5_100 * 86400

# %%
# MRI-CGCM3
evp_cgcm_100 = evspsbl_cgcm.sel(time=slice(None, '1950-12-16'))
evp_cgcm_100C = evp_cgcm_100 * 86400

# %%
evp_awi_100C = evspsbl_awi * 86400

# %%
evp_inm_100 = evspsbl_inm.sel(time=slice(None, '1949-12-16'))
evp_inm_100C = evp_inm_100 * 86400

# %%
evp_mir6_100 = evspsbl_mir6.sel(time=slice(None, '1949-12-16'))
evp_mir6_100C = evp_mir6_100 * 86400

# %%
evp_mpi_100 = evspsbl_mpi.sel(time=slice(None, '1949-12-16'))
evp_mpi_100C = evp_mpi_100 * 86400

# %%
evp_awi_100C = evspsbl_awi * 86400

# %%
evp_inm_100 = evspsbl_inm.sel(time=slice(None, '1949-12-16'))
evp_inm_100C = evp_inm_100 * 86400

# %%
evp_mir6_100 = evspsbl_mir6.sel(time=slice(None, '1949-12-16'))
evp_mir6_100C = evp_mir6_100 * 86400

# %%
evp_mpi_100 = evspsbl_mpi.sel(time=slice(None, '1949-12-16'))
evp_mpi_100C = evp_mpi_100 * 86400

# %% [markdown]
# ### Time average of all the pi data

# %%
# Time-ave for all models
ccsm_m = evp_CCSM_100C.mean(dim='time')
cnrm_m = evp_cnrm_100C.mean(dim='time')
fgo_m = evp_fgo_100C.mean(dim='time')
giss_m = evp_giss_100C.mean(dim='time')

# %%
# continued
ipsl_m = evp_ipsl_100C.mean(dim='time')
mir_m = evp_mir_100C.mean(dim='time')
mpi5_m = evp_mpi5_100C.mean(dim='time')
cgcm_m = evp_cgcm_100C.mean(dim='time')

# %%
# cm6 cintinued 
awi_m = evp_awi_100C.mean(dim='time')
inm_m = evp_inm_100C.mean(dim='time')
mir6_m = evp_mir6_100C.mean(dim='time')
mpi_m = evp_mpi_100C.mean(dim='time')

# %% [markdown]
# ### Seasonal change

# %%
# seasonal change
ccsm_s = evp_CCSM_100C.groupby('time.season').mean(dim='time')
cnrm_s = evp_cnrm_100C.groupby('time.season').mean(dim='time')
fgo_s = evp_fgo_100C.groupby('time.season').mean(dim='time')
giss_s = evp_giss_100C.groupby('time.season').mean(dim='time')

# %%
ipsl_s = evp_ipsl_100C.groupby('time.season').mean(dim='time')
mir_s = evp_mir_100C.groupby('time.season').mean(dim='time')
mpi5_s = evp_mpi5_100C.groupby('time.season').mean(dim='time')
cgcm_s = evp_cgcm_100C.groupby('time.season').mean(dim='time')

# %%
awi_s = evp_awi_100C.groupby('time.season').mean(dim='time')
inm_s = evp_inm_100C.groupby('time.season').mean(dim='time')
mir6_s = evp_mir6_100C.groupby('time.season').mean(dim='time')
mpi_s = evp_mpi_100C.groupby('time.season').mean(dim='time')

# %%
ccsm_mm = pr_CCSM_100C.groupby('time.month').mean(dim='time')
cnrm_mm = pr_cnrm_100C.groupby('time.month').mean(dim='time')
fgo_mm = pr_fgo_100C.groupby('time.month').mean(dim='time')
giss_mm = pr_giss_100C.groupby('time.month').mean(dim='time')

# %%
# ccsm_mml.to_netcdf('ts5_ccsm_mml.nc')
# cnrm_mml.to_netcdf('ts5_cnrm_mml.nc')
# fgo_mml.to_netcdf('ts5_fgo_mml.nc')
# giss_mml.to_netcdf('ts5_giss_mml.nc')

# %%
ipsl_mm = pr_ipsl_100C.groupby('time.month').mean(dim='time')
mir_mm = pr_mir_100C.groupby('time.month').mean(dim='time')
mpi5_mm = pr_mpi5_100C.groupby('time.month').mean(dim='time')
cgcm_mm = pr_cgcm_100C.groupby('time.month').mean(dim='time')

# %%
awi_mm = pr_awi_100C.groupby('time.month').mean(dim='time')
inm_mm = pr_inm_100C.groupby('time.month').mean(dim='time')
mir6_mm = pr_mir6_100C.groupby('time.month').mean(dim='time')
mpi_mm = pr_mpi_100C.groupby('time.month').mean(dim='time')

# %% [markdown]
# ## 3. LGM Anomaly for each model

# %%
# lgm - pi
ccsm_anom = ccsm_ml - ccsm_m
cnrm_anom = cnrm_ml - cnrm_m
fgo_anom = fgo_ml - fgo_m
giss_anom = giss_ml - giss_m

# %%
ipsl_anom = ipsl_ml - ipsl_m
mir_anom = mir_ml - mir_m
mpi5_anom = mpi5_ml - mpi5_m
cgcm_anom = cgcm_ml - cgcm_m

# %%
awi_anom = awi_ml - awi_m
inm_anom = inm_ml - inm_m
mir6_anom = mir6_ml - mir6_m
mpi_anom = mpi_ml - mpi_m

# %%
# ipsl_anom.to_netcdf('ipsl_anom.nc')
# mir_anom.to_netcdf('mir_anom.nc')
# mpi5_anom.to_netcdf('mpi5_anom.nc')
# cgcm_anom.to_netcdf('cgcm_anom.nc')

# %%
# ccsm_anom.to_netcdf('ccsm_anom.nc')
# cnrm_anom.to_netcdf('cnrm_anom.nc')
# fgo_anom.to_netcdf('fgo_anom.nc')
# giss_anom.to_netcdf('giss_anom.nc')

# %%
# awi_anom.to_netcdf('awi_anom.nc')
# inm_anom.to_netcdf('inm_anom.nc')
# mir6_anom.to_netcdf('mir6_anom.nc')
# mpi_anom.to_netcdf('mpi_anom.nc')

# %% [markdown]
# ## 4. Seasonal Change for LGM anomalies

# %%
## lgm - pi
ccsm_anom_s = ccsm_sl - ccsm_s
cnrm_anom_s = cnrm_sl - cnrm_s
fgo_anom_s = fgo_sl - fgo_s
giss_anom_s = giss_sl - giss_s

# %%
ipsl_anom_s = ipsl_sl - ipsl_s
mir_anom_s = mir_sl - mir_s
mpi5_anom_s = mpi5_sl - mpi5_s
cgcm_anom_s = cgcm_sl - cgcm_s

# %%
awi_anom_s = awi_sl - awi_s
inm_anom_s = inm_sl - inm_s
mir6_anom_s = mir6_sl - mir6_s
mpi_anom_s = mpi_sl - mpi_s

# %% [markdown]
# ### JJA season

# %%
## JJA
ccsm_anom_JJA = ccsm_anom_s.sel(season='JJA')
cnrm_anom_JJA = cnrm_anom_s.sel(season='JJA')
fgo_anom_JJA = fgo_anom_s.sel(season='JJA')
giss_anom_JJA = giss_anom_s.sel(season='JJA')

# %%
ipsl_anom_JJAe = ipsl_anom_s.sel(season='JJA')
mir_anom_JJAe = mir_anom_s.sel(season='JJA')
mpi5_anom_JJAe = mpi5_anom_s.sel(season='JJA')
cgcm_anom_JJAe = cgcm_anom_s.sel(season='JJA')

# %%
awi_anom_JJA = awi_anom_s.sel(season='JJA')
inm_anom_JJA = inm_anom_s.sel(season='JJA')
mir6_anom_JJA = mir6_anom_s.sel(season='JJA')
mpi_anom_JJA = mpi_anom_s.sel(season='JJA')

# %%
# ccsm_anom_JJA.to_netcdf('ccsm_anom_JJAe.nc')
# cnrm_anom_JJA.to_netcdf('cnrm_anom_JJAe.nc')
# fgo_anom_JJA.to_netcdf('fgo_anom_JJAe.nc')
# giss_anom_JJA.to_netcdf('giss_anom_JJAe.nc')

# %%
# ipsl_anom_JJAe.to_netcdf('ipsl_anom_JJAe.nc')
# mir_anom_JJAe.to_netcdf('mir_anom_JJAe.nc')
# mpi5_anom_JJAe.to_netcdf('mpi5_anom_JJAe.nc')
# cgcm_anom_JJAe.to_netcdf('cgcm_anom_JJAe.nc')

# %%
# awi_anom_JJA.to_netcdf('awi_anom_JJAe.nc')
# inm_anom_JJA.to_netcdf('inm_anom_JJAe.nc')
# mir6_anom_JJA.to_netcdf('mir6_anom_JJAe.nc')
# mpi_anom_JJA.to_netcdf('mpi_anom_JJAe.nc')

# %% [markdown]
# ### DJF season

# %%
## DJF
ccsm_anom_DJF = ccsm_anom_s.sel(season='DJF')
cnrm_anom_DJF = cnrm_anom_s.sel(season='DJF')
fgo_anom_DJF = fgo_anom_s.sel(season='DJF')
giss_anom_DJF = giss_anom_s.sel(season='DJF')

# %%
ipsl_anom_DJFe = ipsl_anom_s.sel(season='DJF')
mir_anom_DJFe = mir_anom_s.sel(season='DJF')
mpi5_anom_DJFe = mpi5_anom_s.sel(season='DJF')
cgcm_anom_DJFe = cgcm_anom_s.sel(season='DJF')

# %%
awi_anom_DJF = awi_anom_s.sel(season='DJF')
inm_anom_DJF = inm_anom_s.sel(season='DJF')
mir6_anom_DJF = mir6_anom_s.sel(season='DJF')
mpi_anom_DJF = mpi_anom_s.sel(season='DJF')

# %%
# ccsm_anom_DJF.to_netcdf('ccsm_anom_DJFe.nc')
# cnrm_anom_DJF.to_netcdf('cnrm_anom_DJFe.nc')
# fgo_anom_DJF.to_netcdf('fgo_anom_DJFe.nc')
# giss_anom_DJF.to_netcdf('giss_anom_DJFe.nc')

# %%
# ipsl_anom_DJFe.to_netcdf('ipsl_anom_DJFe.nc')
# mir_anom_DJFe.to_netcdf('mir_anom_DJFe.nc')
# mpi5_anom_DJFe.to_netcdf('mpi5_anom_DJFe.nc')
# cgcm_anom_DJFe.to_netcdf('cgcm_anom_DJFe.nc')

# %%
# awi_anom_DJF.to_netcdf('awi_anom_DJFe.nc')
# inm_anom_DJF.to_netcdf('inm_anom_DJFe.nc')
# mir6_anom_DJF.to_netcdf('mir6_anom_DJFe.nc')
# mpi_anom_DJF.to_netcdf('mpi_anom_DJFe.nc')

# %% [markdown]
# ## 5. MMM annual mean Australian spatial plot (Fig.9)

# %% [markdown]
# ### LGM MMM calculation

# %%
## all model MMM
mmm_evp_lgm = (ccsm_ml + cnrm_ml + fgo_ml + giss_ml + ipsl_ml + mir_ml + mpi5_ml + cgcm_ml + awi_ml+inm_ml+mir6_ml+mpi_ml)/12
mmm_evp_lgm
# Out:
# <xarray.DataArray 'evspsbl' (lat: 120, lon: 240)>
# array([[0.01322524, 0.01318745, 0.01314687, ..., 0.01334041, 0.01329228,
#         0.01326588],
#        [0.00825266, 0.0082618 , 0.00824359, ..., 0.01051584, 0.00979219,
#         0.00895729],
#        [0.00875005, 0.0092749 , 0.0098831 , ..., 0.00931423, 0.00916212,
#         0.00897212],
#        ...,
#        [0.07094299, 0.07098542, 0.07094087, ..., 0.07296663, 0.07335121,
#         0.07162783],
#        [0.07186905, 0.07199619, 0.0721276 , ..., 0.07173176, 0.07146215,
#         0.07160019],
#        [0.06783784, 0.06794782, 0.06802304, ..., 0.06735692, 0.06709364,
#         0.06748345]])
# Coordinates:
#   * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25

# %%
# mmm_evp_lgm.to_netcdf('mmm_evp_lgm.nc')

# %% [markdown]
# ### PI MMM calculation

# %%
## all pi model MMM
mmm_evp_pi = (ccsm_m + cnrm_m + fgo_m + giss_m + ipsl_m + mir_m + mpi5_m + cgcm_m + awi_m+inm_m+mir6_m+mpi_m)/12
mmm_evp_pi
# Out:
# <xarray.DataArray 'evspsbl' (lat: 120, lon: 240)>
# array([[0.00801791, 0.00792081, 0.00793356, ..., 0.00807275, 0.00814439,
#         0.00814287],
#        [0.00896041, 0.00890172, 0.00866043, ..., 0.00925535, 0.00920705,
#         0.00907483],
#        [0.01104575, 0.01046716, 0.00992774, ..., 0.0123383 , 0.01187619,
#         0.01146687],
#        ...,
#        [0.11382712, 0.11409025, 0.11465645, ..., 0.11380052, 0.11370783,
#         0.11360558],
#        [0.10836846, 0.10861856, 0.10889992, ..., 0.10832149, 0.10832312,
#         0.1083778 ],
#        [0.10488119, 0.10505303, 0.10522408, ..., 0.10449364, 0.10455129,
#         0.10472756]])
# Coordinates:
#   * lon      (lon) float64 0.0 1.5 3.0 4.5 6.0 ... 352.5 354.0 355.5 357.0 358.5
#   * lat      (lat) float64 -89.25 -87.75 -86.25 -84.75 ... 86.25 87.75 89.25

# %%
# mmm_evp_pi.to_netcdf('mmm_evp_pi.nc')

# %% [markdown]
# ### LGM - PI P - E anom

# %%
# MMM Pr lgm - pi anomaly read in
ds11_cm999 = xr.open_dataset('mmm_pr_anom_update.nc')
mmm_pr_anom = ds11_cm999.pr

# %%
# MMM Evap lgm - pi
ds11_cmpi = xr.open_dataset('mmm_evp_pi.nc')
mmm_evp_pi = ds11_cmpi.evspsbl
ds11_cmlgm = xr.open_dataset('mmm_evp_lgm.nc')
mmm_evp_lgm = ds11_cmlgm.evspsbl
mmm_evp_anom = mmm_evp_lgm - mmm_evp_pi

# %%
# MMM lgm-pi P - E
mmm_PE_anom = mmm_pr_anom - mmm_evp_anom

# %% [markdown]
# ### make the Australian plot

# %%
# MMM mean annual P vs P-E
f = plt.figure(figsize=(16,9))
axs = []

ax = f.add_subplot(131, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_pr_anom.lon, mmm_pr_anom.lat, mmm_pr_anom, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.4, label='mm / day')
ax.set_title('a) LGM - PI Precipitation', loc='left',fontsize=13)
# ax.set_yticks(lat,'Latitude')
# # ax.set_ylabel('Latitude',fontsize=12)
# ax.set_xticks(lon,'Longitute')
# # ax.set_xlabel('Longitute',fontsize=12)
# axs.append(ax)

ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)

ax = f.add_subplot(132, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_evp_anom.lon, mmm_evp_anom.lat, mmm_evp_anom, transform=ccrs.PlateCarree(), cmap='RdBu_r')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.4, label='mm / day')
ax.set_title('b) LGM - PI Evapotranspiration', loc='left',fontsize=13)
# ax.set_yticks(lat,'Latitude')
# # ax.set_ylabel('Latitude',fontsize=12)
# ax.set_xticks(lon,'Longitute')
# # ax.set_xlabel('Longitute',fontsize=12)
# axs.append(ax)

ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)

ax = f.add_subplot(133, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_PE_anom.lon, mmm_PE_anom.lat, mmm_PE_anom, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.4, label='mm / day')
ax.set_title('c) LGM - PI Precip. minus evap.', loc='left',fontsize=13)
# ax.set_yticks(lat,'Latitude')
# # ax.set_ylabel('Latitude',fontsize=12)
# ax.set_xticks(lon,'Longitute')
# # ax.set_xlabel('Longitute',fontsize=12)
# axs.append(ax)

ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)

# plt.savefig('fig6paper_update.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 6. MMM seasonal P-E Austraian spatial plot (Fig.10)

# %% [markdown]
# ### Seasonal LGM - Pi P - E

# %%
# P lgm anom
dss_cmll = xr.open_dataset('mmm_pr_season_anom_update.nc')
mmm_pr_season_anom = dss_cmll.pr

# %%
# seasonal lgm - pi P
mmm_JJA_anomp = mmm_pr_season_anom.sel(season='JJA')
mmm_DJF_anomp = mmm_pr_season_anom.sel(season='DJF')
mmm_MAM_anomp = mmm_pr_season_anom.sel(season='MAM')
mmm_SON_anomp = mmm_pr_season_anom.sel(season='SON')

# %%
# read in seasonal evap. data
dss_cml = xr.open_dataset('mmm_evp_season_lgm.nc')
mmm_evp_season_lgm = dss_cml.evspsbl
dss_cmli = xr.open_dataset('mmm_evp_season_pi.nc')
mmm_evp_season_pi = dss_cmli.evspsbl
# lgm - pi evap.
mmm_evp_anom = mmm_evp_season_lgm - mmm_evp_season_pi

# %%
# seasonal lgm - pi E
mmm_JJA_anom = mmm_evp_anom.sel(season='JJA')
mmm_DJF_anom = mmm_evp_anom.sel(season='DJF')
mmm_MAM_anom = mmm_evp_anom.sel(season='MAM')
mmm_SON_anom = mmm_evp_anom.sel(season='SON')

# %%
# seasonal lgm-pi P-E
mmm_JJA_PE_anom = mmm_JJA_anomp - mmm_JJA_anom
mmm_DJF_PE_anom = mmm_DJF_anomp - mmm_DJF_anom
mmm_MAM_PE_anom = mmm_MAM_anomp - mmm_MAM_anom
mmm_SON_PE_anom = mmm_SON_anomp - mmm_SON_anom

# %% [markdown]
# ### Make MMM seasonal P-E plot

# %%
fig = plt.figure(figsize=(11,9))
axs = []

ax = fig.add_subplot(221, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_DJF_PE_anom.lon, mmm_DJF_PE_anom.lat, mmm_DJF_PE_anom, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.85, label='mm / day')
ax.set_title('a) DJF LGM - PI Precip. minus Evap.', loc='left')
ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)

# ax.text(0.1, 0.04, 'Land Average: -0.262 mm/day ', transform=ax.transAxes, fontsize=12)
ax = fig.add_subplot(222, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_MAM_PE_anom.lon, mmm_MAM_PE_anom.lat, mmm_MAM_PE_anom, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
im.set_clim(-2,2)
plt.colorbar(im, ax=ax, shrink=0.85, label='mm / day')
ax.set_title('b) MAM LGM - PI Precip. minus Evap.', loc='left')
ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)


ax = fig.add_subplot(223, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_JJA_PE_anom.lon, mmm_JJA_PE_anom.lat, mmm_JJA_PE_anom, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.85, label='mm / day')
ax.set_title('c) JJA LGM - PI Precip. minus Evap.', loc='left')
ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)


ax = fig.add_subplot(224, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_SON_PE_anom.lon, mmm_SON_PE_anom.lat, mmm_SON_PE_anom, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.85, label='mm / day')
ax.set_title('d) SON LGM - PI Precip. minus Evap.', loc='left')
ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)


plt.tight_layout()

# plt.savefig('PE_anom_s.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 7. MMM seasonal evapotranspiration plot over Australia (Supplement Fig.S4)

# %%
fig = plt.figure(figsize=(11,9))
axs = []

ax = fig.add_subplot(221, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_DJF_anom.lon, mmm_DJF_anom.lat, mmm_DJF_anom, transform=ccrs.PlateCarree(), cmap='RdBu_r')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.85, label='mm / day')
ax.set_title('a) DJF LGM - PI Evapotranspiration', loc='left')
ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)

# ax.text(0.1, 0.04, 'Land Average: -0.262 mm/day ', transform=ax.transAxes, fontsize=12)
ax = fig.add_subplot(222, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_MAM_anom.lon, mmm_MAM_anom.lat, mmm_MAM_anom, transform=ccrs.PlateCarree(), cmap='RdBu_r')
ax.coastlines()
im.set_clim(-2,2)
plt.colorbar(im, ax=ax, shrink=0.85, label='mm / day')
ax.set_title('b) MAM LGM - PI Evapotranspiration', loc='left')
ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)


ax = fig.add_subplot(223, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_JJA_anom.lon, mmm_JJA_anom.lat, mmm_JJA_anom, transform=ccrs.PlateCarree(), cmap='RdBu_r')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.85, label='mm / day')
ax.set_title('c) JJA LGM - PI Evapotranspiration', loc='left')
ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)


ax = fig.add_subplot(224, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
im = ax.pcolormesh(mmm_SON_anom.lon, mmm_SON_anom.lat, mmm_SON_anom, transform=ccrs.PlateCarree(), cmap='RdBu_r')
ax.coastlines()
im.set_clim(-2, 2)
plt.colorbar(im, ax=ax, shrink=0.85, label='mm / day')
ax.set_title('d) SON LGM - PI Evapotranspiration', loc='left')
ax.set_xticks([110, 120, 130, 140, 150, 160], crs=ccrs.PlateCarree())
ax.set_yticks([-40, -30, -20, -10, 0], crs=ccrs.PlateCarree())

lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
axs.append(ax)


plt.tight_layout()

# plt.savefig('evap_anom_s.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 8. Making annual mean individual P-E plot (Supplement Fig.S5)

# %% [markdown]
# ### Reload annual E anom

# %%
ds1_cm5 = xr.open_dataset('ccsm_anom.nc')
ccsm_anome = ds1_cm5.evspsbl

# %%
ds2_cm5 = xr.open_dataset('cnrm_anom.nc')
cnrm_anome = ds2_cm5.evspsbl

# %%
ds3_cm5 = xr.open_dataset('fgo_anom.nc')
fgo_anome = ds3_cm5.evspsbl

# %%
ds4_cm5 = xr.open_dataset('giss_anom.nc')
giss_anome = ds4_cm5.evspsbl

# %%
ds5_cm5 = xr.open_dataset('ipsl_anom.nc')
ipsl_anome = ds5_cm5.evspsbl

# %%
ds8_cm5 = xr.open_dataset('cgcm_anom.nc')
cgcm_anome = ds8_cm5.evspsbl

# %%
ds6_cm5 = xr.open_dataset('mir_anom.nc')
mir_anome = ds6_cm5.evspsbl

# %%
ds7_cm5 = xr.open_dataset('mpi5_anom.nc')
mpi5_anome = ds7_cm5.evspsbl

# %%
d1_cm5 = xr.open_dataset('awi_anom.nc')
awi_anome = d1_cm5.evspsbl

# %%
ds88_cm5 = xr.open_dataset('inm_anom.nc')
inm_anome = ds88_cm5.evspsbl

# %%
ds68_cm5 = xr.open_dataset('mir6_anom.nc')
mir6_anome = ds68_cm5.evspsbl

# %%
ds78_cm5 = xr.open_dataset('mpi_anom.nc')
mpi_anome = ds78_cm5.evspsbl

# %% [markdown]
# ### Reload annual P anom

# %%
ds1_cm5 = xr.open_dataset('ccsm_anom1.nc')
ccsm_anomp = ds1_cm5.pr

# %%
ds2_cm5 = xr.open_dataset('cnrm_anom1.nc')
cnrm_anomp = ds2_cm5.pr

# %%
ds3_cm5 = xr.open_dataset('fgo_anom1.nc')
fgo_anomp = ds3_cm5.pr

# %%
ds4_cm5 = xr.open_dataset('giss_anom1.nc')
giss_anomp = ds4_cm5.pr

# %%
ds5_cm5 = xr.open_dataset('ipsl_anom1.nc')
ipsl_anomp = ds5_cm5.pr

# %%
ds8_cm5 = xr.open_dataset('cgcm_anom1.nc')
cgcm_anomp = ds8_cm5.pr

# %%
ds6_cm5 = xr.open_dataset('mir_anom1.nc')
mir_anomp = ds6_cm5.pr

# %%
ds7_cm5 = xr.open_dataset('mpi5_anom1.nc')
mpi5_anomp = ds7_cm5.pr

# %%
d1_cm5 = xr.open_dataset('awi_anom1.nc')
awi_anomp = d1_cm5.pr

# %%
ds88_cm5 = xr.open_dataset('inm_anom1.nc')
inm_anomp = ds88_cm5.pr

# %%
ds68_cm5 = xr.open_dataset('mir6_anom1.nc')
mir6_anomp = ds68_cm5.pr

# %%
ds78_cm5 = xr.open_dataset('mpi_anom1.nc')
mpi_anomp = ds78_cm5.pr

# %% [markdown]
# ### annual P - E anom

# %%
cnrm_anom = cnrm_anomp - cnrm_anome
ccsm_anom = ccsm_anomp - ccsm_anome
fgo_anom = fgo_anomp - fgo_anome
giss_anom = giss_anomp - giss_anome

# %%
ipsl_anom = ipsl_anomp - ipsl_anome
cgcm_anom = cgcm_anomp - cgcm_anome
mir_anom = mir_anomp - mir_anome
mpi5_anom = mpi5_anomp - mpi5_anome

# %%
awi_anom = awi_anomp - awi_anome
inm_anom = inm_anomp - inm_anome
mir6_anom = mir6_anomp - mir6_anome
mpi_anom = mpi_anomp - mpi_anome

# %% [markdown]
# ### Making annual mean individual P-E plot

# %%
# Annual Mean
fig = plt.figure(figsize=(23,13))
axs = []

vmin = -2.5
vmax = 2.5


ax = fig.add_subplot(341, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = ccsm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 CCSM4')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3188', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(342, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = cnrm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 CNRM-CM5')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4375', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(343, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = fgo_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 FGOALS-g2')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3397', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(344, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = giss_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 GISS-E2-R')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2044', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(345, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = ipsl_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 IPSL-CM5A-LR')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.1131', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(346, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mir_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MIROC-ESM')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3427', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(347, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mpi5_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MPI-ESM-P')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2521', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(348, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = cgcm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MRI-CGCM3')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4833', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(349, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = awi_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 AWI-ESM-1-1-LR')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4314', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,10, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = inm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 INM-CM4-8')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4041', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,11, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mir6_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 MIROC-ES2L')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3995', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,12, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mpi_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 MPI-ESM1-2-LR')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2659', transform=ax.transAxes, fontsize=12)


cbar = plt.colorbar(C, ax=axs, shrink=0.5)
cbar.ax.set_ylabel('Precip. minus Evap. (mm / day)', fontsize=14)

# plt.savefig('p-e_annualmodels_compare.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 9. Making DJF individual P-E plot (Supplement Fig.S6)

# %% [markdown]
# ### Reload DJF P

# %%
# reload p data
ds1_cm5 = xr.open_dataset('ccsm_anom_DJF.nc')
ccsm_anom_DJFp = ds1_cm5.pr

# %%
ds2_cm5 = xr.open_dataset('cnrm_anom_DJF.nc')
cnrm_anom_DJFp = ds2_cm5.pr

# %%
ds3_cm5 = xr.open_dataset('fgo_anom_DJF.nc')
fgo_anom_DJFp = ds3_cm5.pr

# %%
ds4_cm5 = xr.open_dataset('giss_anom_DJF.nc')
giss_anom_DJFp = ds4_cm5.pr

# %%
ds5_cm5 = xr.open_dataset('awi_anom_DJF.nc')
awi_anom_DJFp = ds5_cm5.pr

# %%
ds8_cm5 = xr.open_dataset('inm_anom_DJF.nc')
inm_anom_DJFp = ds8_cm5.pr

# %%
ds6_cm5 = xr.open_dataset('mir6_anom_DJF.nc')
mir6_anom_DJFp = ds6_cm5.pr

# %%
ds7_cm5 = xr.open_dataset('mpi_anom_DJF.nc')
mpi_anom_DJFp = ds7_cm5.pr

# %%
ds5_cm5 = xr.open_dataset('ipsl_anom_DJF.nc')
ipsl_anom_DJFp = ds5_cm5.pr

# %%
ds8_cm5 = xr.open_dataset('cgcm_anom_DJF.nc')
cgcm_anom_DJFp = ds8_cm5.pr

# %%
ds6_cm5 = xr.open_dataset('mir_anom_DJF.nc')
mir_anom_DJFp = ds6_cm5.pr

# %%
ds7_cm5 = xr.open_dataset('mpi5_anom_DJF.nc')
mpi5_anom_DJFp = ds7_cm5.pr

# %% [markdown]
# ### Reload DJF E data

# %%
ds1_cm5 = xr.open_dataset('ccsm_anom_DJFe.nc')
ccsm_anom_DJFe = ds1_cm5.evspsbl

# %%
ds2_cm5 = xr.open_dataset('cnrm_anom_DJFe.nc')
cnrm_anom_DJFe = ds2_cm5.evspsbl

# %%
ds3_cm5 = xr.open_dataset('fgo_anom_DJFe.nc')
fgo_anom_DJFe = ds3_cm5.evspsbl

# %%
ds4_cm5 = xr.open_dataset('giss_anom_DJFe.nc')
giss_anom_DJFe = ds4_cm5.evspsbl

# %%
ds5_cm5 = xr.open_dataset('awi_anom_DJFe.nc')
awi_anom_DJFe = ds5_cm5.evspsbl

# %%
ds8_cm5 = xr.open_dataset('inm_anom_DJFe.nc')
inm_anom_DJFe = ds8_cm5.evspsbl

# %%
ds6_cm5 = xr.open_dataset('mir6_anom_DJFe.nc')
mir6_anom_DJFe = ds6_cm5.evspsbl

# %%
ds7_cm5 = xr.open_dataset('mpi_anom_DJFe.nc')
mpi_anom_DJFe = ds7_cm5.evspsbl

# %%
ds5_cm5 = xr.open_dataset('ipsl_anom_DJFe.nc')
ipsl_anom_DJFe = ds5_cm5.evspsbl

# %%
ds8_cm5 = xr.open_dataset('cgcm_anom_DJFe.nc')
cgcm_anom_DJFe = ds8_cm5.evspsbl

# %%
ds6_cm5 = xr.open_dataset('mir_anom_DJFe.nc')
mir_anom_DJFe = ds6_cm5.evspsbl

# %%
ds7_cm5 = xr.open_dataset('mpi5_anom_DJFe.nc')
mpi5_anom_DJFe = ds7_cm5.evspsbl

# %% [markdown]
# ### DJF P - E anom

# %%
cnrm_anom = cnrm_anom_DJFp - cnrm_anom_DJFe
ccsm_anom = ccsm_anom_DJFp - ccsm_anom_DJFe
fgo_anom = fgo_anom_DJFp - fgo_anom_DJFe
giss_anom = giss_anom_DJFp - giss_anom_DJFe

# %%
ipsl_anom = ipsl_anom_DJFp - ipsl_anom_DJFe
cgcm_anom = cgcm_anom_DJFp - cgcm_anom_DJFe
mir_anom = mir_anom_DJFp - mir_anom_DJFe
mpi5_anom = mpi5_anom_DJFp - mpi5_anom_DJFe

# %%
awi_anom = awi_anom_DJFp - awi_anom_DJFe
inm_anom = inm_anom_DJFp - inm_anom_DJFe
mir6_anom = mir6_anom_DJFp - mir6_anom_DJFe
mpi_anom = mpi_anom_DJFp - mpi_anom_DJFe

# %% [markdown]
# ### individual DJF P-E plot

# %%
fig = plt.figure(figsize=(23,13))
axs = []

vmin = -3.5
vmax = 3.5


ax = fig.add_subplot(341, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = ccsm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 CCSM4 DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3188', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(342, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = cnrm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 CNRM-CM5 DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4375', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(343, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = fgo_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 FGOALS-g2 DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3397', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(344, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = giss_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 GISS-E2-R DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2044', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(345, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = ipsl_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 IPSL-CM5A-LR DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.1131', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(346, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mir_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MIROC-ESM DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3427', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(347, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mpi5_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MPI-ESM-P DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2521', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(348, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = cgcm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MRI-CGCM3 DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4833', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(349, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = awi_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 AWI-ESM-1-1-LR DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4314', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,10, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = inm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 INM-CM4-8 DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4041', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,11, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mir6_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 MIROC-ES2L DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3995', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,12, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mpi_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 MPI-ESM1-2-LR DJF')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2659', transform=ax.transAxes, fontsize=12)


cbar = plt.colorbar(C, ax=axs, shrink=0.5)
cbar.ax.set_ylabel('Precip. minus Evap. (mm / day)', fontsize=14)

# plt.savefig('DJF_p-e_models_compare.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## 10. Making JJA individual P-E plot (Supplement Fig.S7)

# %% [markdown]
# ### Reload JJA E

# %%
ds1_cm5 = xr.open_dataset('ccsm_anom_JJAe.nc')
ccsm_anom_JJAe = ds1_cm5.evspsbl

# %%
ds2_cm5 = xr.open_dataset('cnrm_anom_JJAe.nc')
cnrm_anom_JJAe = ds2_cm5.evspsbl

# %%
ds3_cm5 = xr.open_dataset('fgo_anom_JJAe.nc')
fgo_anom_JJAe = ds3_cm5.evspsbl

# %%
ds4_cm5 = xr.open_dataset('giss_anom_JJAe.nc')
giss_anom_JJAe = ds4_cm5.evspsbl

# %%
ds5_cm5 = xr.open_dataset('awi_anom_JJAe.nc')
awi_anom_JJAe = ds5_cm5.evspsbl

# %%
ds8_cm5 = xr.open_dataset('inm_anom_JJAe.nc')
inm_anom_JJAe = ds8_cm5.evspsbl

# %%
ds6_cm5 = xr.open_dataset('mir6_anom_JJAe.nc')
mir6_anom_JJAe = ds6_cm5.evspsbl

# %%
ds7_cm5 = xr.open_dataset('mpi_anom_JJAe.nc')
mpi_anom_JJAe = ds7_cm5.evspsbl

# %%
ds5_cm5 = xr.open_dataset('ipsl_anom_JJAe.nc')
ipsl_anom_JJAe = ds5_cm5.evspsbl

# %%
ds8_cm5 = xr.open_dataset('cgcm_anom_JJAe.nc')
cgcm_anom_JJAe = ds8_cm5.evspsbl

# %%
ds6_cm5 = xr.open_dataset('mir_anom_JJAe.nc')
mir_anom_JJAe = ds6_cm5.evspsbl

# %%
ds7_cm5 = xr.open_dataset('mpi5_anom_JJAe.nc')
mpi5_anom_JJAe = ds7_cm5.evspsbl

# %% [markdown]
# ### Reload JJA P data

# %%
ds1_cm5 = xr.open_dataset('ccsm_anom_JJA.nc')
ccsm_anom_JJAp = ds1_cm5.pr

# %%
ds2_cm5 = xr.open_dataset('cnrm_anom_JJA.nc')
cnrm_anom_JJAp = ds2_cm5.pr

# %%
ds3_cm5 = xr.open_dataset('fgo_anom_JJA.nc')
fgo_anom_JJAp = ds3_cm5.pr

# %%
ds4_cm5 = xr.open_dataset('giss_anom_JJA.nc')
giss_anom_JJAp = ds4_cm5.pr

# %%
ds5_cm5 = xr.open_dataset('awi_anom_JJA.nc')
awi_anom_JJAp = ds5_cm5.pr

# %%
ds8_cm5 = xr.open_dataset('inm_anom_JJA.nc')
inm_anom_JJAp = ds8_cm5.pr

# %%
ds6_cm5 = xr.open_dataset('mir6_anom_JJA.nc')
mir6_anom_JJAp = ds6_cm5.pr

# %%
ds7_cm5 = xr.open_dataset('mpi_anom_JJA.nc')
mpi_anom_JJAp = ds7_cm5.pr

# %%
ds5_cm5 = xr.open_dataset('ipsl_anom_JJA.nc')
ipsl_anom_JJAp = ds5_cm5.pr

# %%
ds8_cm5 = xr.open_dataset('cgcm_anom_JJA.nc')
cgcm_anom_JJAp = ds8_cm5.pr

# %%
ds6_cm5 = xr.open_dataset('mir_anom_JJA.nc')
mir_anom_JJAp = ds6_cm5.pr

# %%
ds7_cm5 = xr.open_dataset('mpi5_anom_JJA.nc')
mpi5_anom_JJAp = ds7_cm5.pr

# %% [markdown]
# ### JJA P - E anom

# %%
cnrm_anom = cnrm_anom_JJAp - cnrm_anom_JJAe
ccsm_anom = ccsm_anom_JJAp - ccsm_anom_JJAe
fgo_anom = fgo_anom_JJAp - fgo_anom_JJAe
giss_anom = giss_anom_JJAp - giss_anom_JJAe

# %%
ipsl_anom = ipsl_anom_JJAp - ipsl_anom_JJAe
cgcm_anom = cgcm_anom_JJAp - cgcm_anom_JJAe
mir_anom = mir_anom_JJAp - mir_anom_JJAe
mpi5_anom = mpi5_anom_JJAp - mpi5_anom_JJAe

# %%
awi_anom = awi_anom_JJAp - awi_anom_JJAe
inm_anom = inm_anom_JJAp - inm_anom_JJAe
mir6_anom = mir6_anom_JJAp - mir6_anom_JJAe
mpi_anom = mpi_anom_JJAp - mpi_anom_JJAe

# %% [markdown]
# ### individual JJA P-E plot

# %%
# Annual Mean
fig = plt.figure(figsize=(23,13))
axs = []

vmin = -3.5
vmax = 3.5


ax = fig.add_subplot(341, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = ccsm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 CCSM4 JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3188', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(342, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = cnrm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 CNRM-CM5 JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4375', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(343, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = fgo_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 FGOALS-g2 JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3397', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(344, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = giss_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 GISS-E2-R JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2044', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(345, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = ipsl_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 IPSL-CM5A-LR JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.1131', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(346, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mir_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MIROC-ESM JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3427', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(347, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mpi5_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MPI-ESM-P JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2521', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(348, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = cgcm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP5 MRI-CGCM3 JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4833', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(349, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = awi_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 AWI-ESM-1-1-LR JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4314', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,10, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = inm_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 INM-CM4-8 JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.4041', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,11, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mir6_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 MIROC-ES2L JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.3995', transform=ax.transAxes, fontsize=12)

ax = fig.add_subplot(3,4,12, projection=ccrs.PlateCarree())
ax.set_extent([110, 160, -42.5, 0])
C = mpi_anom.plot(ax=ax, vmin=vmin, vmax=vmax, add_colorbar=False, transform=ccrs.PlateCarree(), cmap='RdBu')
ax.coastlines()
ax.set_title('CMIP6 MPI-ESM1-2-LR JJA')
axs.append(ax)
# ax.text(0.03, 0.05, 'Land Average: -0.2659', transform=ax.transAxes, fontsize=12)


cbar = plt.colorbar(C, ax=axs, shrink=0.5)
cbar.ax.set_ylabel('Precip. minus Evap. (mm / day)', fontsize=14)

# plt.savefig('JJA_p-e_models_compare.jpg', dpi=300, bbox_inches='tight')
